# %% [markdown]
# # NG11
# COVID-19 Indonesia Dataset
# Based on reports from official sources
# - Cari Measure of Central Tendency dari data tersebut.
# - Cari Measure of Variance dari data tersebut.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("covid_19_indonesia_time_series_all.csv")

# %%
df.head()
# Out:
#         Date Location ISO Code    Location  New Cases  New Deaths  \
# 0   1/8/2020             ID-JI  Jawa Timur          9           3
# 1   1/9/2020             ID-JI  Jawa Timur          0           1
# 2  1/10/2020             ID-JI  Jawa Timur          0           1
# 3  1/11/2020             ID-JI  Jawa Timur          0           3
# 4  1/12/2020             ID-JI  Jawa Timur          0           3
#
#    New Recovered  New Active Cases  Total Cases  Total Deaths  \
# 0              1                 5            9             5
# 1             23               -24            9             6
# 2             14               -15            9             7
# 3              8               -11            9            10
# 4              1                -4            9            13
#
#    Total Recovered  ...  New Deaths per Million Total Deaths per Million  \
# 0               10  ...                    0.07                     0.12
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16283 entries, 0 to 16282
# Data columns (total 41 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         16283 non-null  object
#  1   Location ISO Code            16283 non-null  object
#  2   Location                     16283 non-null  object
#  3   New Cases                    16283 non-null  int64
#  4   New Deaths                   16283 non-null  int64
#  5   New Recovered                16283 non-null  int64
#  6   New Active Cases             16283 non-null  int64
#  7   Total Cases                  16283 non-null  int64
#  8   Total Deaths                 16283 non-null  int64
#  9   Total Recovered              16283 non-null  int64
#  10  Total Active Cases           16283 non-null  int64
#  11  Location Level               16283 non-null  object
#  12  City or Regency              0 non-null      float64
# ...

# %% [markdown]
# ### Measure of Central Tendency

# %%
#Summary of data distribution
df.describe().T
# Out:
#                                count          mean           std  \
# New Cases                    16283.0  3.012719e+02  1.330028e+03
# New Deaths                   16283.0  7.919364e+00  3.217143e+01
# New Recovered                16283.0  2.480158e+02  9.977849e+02
# New Active Cases             16283.0  4.533673e+01  5.502037e+02
# Total Cases                  16283.0  4.274674e+04  1.784936e+05
# Total Deaths                 16283.0  1.243918e+03  4.944635e+03
# Total Recovered              16283.0  3.689427e+04  1.580017e+05
# Total Active Cases           16283.0  4.608550e+03  1.767008e+04
# City or Regency                  0.0           NaN           NaN
# Total Regencies              16283.0  2.479291e+01  6.965883e+01
# Total Cities                 15814.0  6.049576e+00  1.670124e+01
# Total Districts              16283.0  4.325953e+02  1.215580e+03
# Total Urban Villages         15812.0  5.244581e+02  1.448924e+03
# ...

# %%
#Modus value
df['New Cases'].mode()[0]
# Out:
# 0

# %% [markdown]
# ### Measure of Variance

# %%
#Range of data value
datacols = ['New Cases', 'New Deaths', 'New Recovered', 'New Active Cases', 'Total Cases', 'Total Deaths',
           'Total Recovered','Total Active Cases']
for i in datacols:
    print(df[i].name + ' range: ' + str(df[i].max() - df[i].min()))
# Out:
# New Cases range: 38391
# New Deaths range: 1040
# New Recovered range: 28975
# New Active Cases range: 26885
# Total Cases range: 2455911
# Total Deaths range: 64631
# Total Recovered range: 2023548
# Total Active Cases range: 370128

# %%
#Quantile/quartile
print(df['New Cases'].quantile([0.25, 0.5, 0.75]))
# Out:
# 0.25      6.0
# 0.50     39.0
# 0.75    127.0
# Name: New Cases, dtype: float64

# %%
# Plot a box-whisker chart
df['New Cases'].plot(kind='box', title='New Cases Distribution', figsize=(10,8))
plt.show()

# %%
# Plot a box-whisker chart without outliers
df['New Cases'].plot(kind='box', title='New Cases Distribution', figsize=(10,8), showfliers=False)
plt.show()

# %%
#New Cases variance and standard deviation
print('Var :',df['New Cases'].var())
print('Std :',df['New Cases'].std())
# Out:
# Var : 1768975.0113863915
# Std : 1330.028199470369
