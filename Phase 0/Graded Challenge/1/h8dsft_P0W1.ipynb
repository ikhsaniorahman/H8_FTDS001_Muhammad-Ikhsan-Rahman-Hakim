# %% [markdown]
# *Graded Challenge 1*

# %% [markdown]
# # Data Analysis on Pokemon's Dataset

# %% [markdown]
# Muhammad Ikhsan Rahman Hakim - FTDS001

# %% [markdown]
# Kumpulan data ini berisi 721 Pokemon , termasuk nomor, nama, tipe pertama dan kedua, dan statistik dasar: HP, Serangan, Pertahanan, Serangan Khusus, Pertahanan Khusus, dan Kecepatan. Dataset ini diambil dari game pokemon (Bukan kartu (trading card) Pokemon atau Pokemon Go).
#
# Dengan menganalisa dataset ini diharapkan dapat menjawab beberapa pertanyaan umum tentang Pokemon seperti, "Berapa banyak jumlah keseluruhan pokemon?", "Tipe pokemon apa yang paling banyak?", dan lainnya.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Mengimport library packages yang dibutuhkan

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Membaca file csv menggunakan pandas

# %%
df = pd.read_csv(r"C:\Users\mistersunday\Documents\Hacktiv8 resource\GC phase 0\Pokemon.csv")

# %% [markdown]
# ## Basic info from dataset

# %% [markdown]
# Memberikan sekilas gambaran tentang 5 elemen pertama dan terakhir dari Dataset

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.tail()
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %% [markdown]
# Dari df.shape kita dapat mengetahui jumlah baris dan kolom dataset

# %%
df.shape
# Out:
# (800, 13)

# %% [markdown]
# Menggunakan df.info() untuk mengetahui jumlah data Non-null, type data, dan kolom

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %% [markdown]
# Menggunakan df.describe() untuk memberikan ringkasan statistik dari dataset.

# %%
df.describe().T
# Out:
#             count       mean         std    min     25%    50%     75%    max
# #           800.0  362.81375  208.343798    1.0  184.75  364.5  539.25  721.0
# Total       800.0  435.10250  119.963040  180.0  330.00  450.0  515.00  780.0
# HP          800.0   69.25875   25.534669    1.0   50.00   65.0   80.00  255.0
# Attack      800.0   79.00125   32.457366    5.0   55.00   75.0  100.00  190.0
# Defense     800.0   73.84250   31.183501    5.0   50.00   70.0   90.00  230.0
# Sp. Atk     800.0   72.82000   32.722294   10.0   49.75   65.0   95.00  194.0
# Sp. Def     800.0   71.90250   27.828916   20.0   50.00   70.0   90.00  230.0
# Speed       800.0   68.27750   29.060474    5.0   45.00   65.0   90.00  180.0
# Generation  800.0    3.32375    1.661290    1.0    2.00    3.0    5.00    6.0

# %% [markdown]
# ### Variable Information

# %% [markdown]
# - #: Each Pokemon's ID.
#
# - Name: Name of each pokemon
#
# - Type 1: The primary type of each Pokemon which determines their strengths and weaknesses.
#
# - Type 2: The secundary type for each Pokemon, which determines their secondary strengths and weaknesses.
#
# - Total: The sum of all the other stats
#
# - HP: hit points, or health, defines how much damage a pokemon can withstand before fainting.
#
# - Attack: the base modifier for normal attacks (eg. Scratch, Punch).
#
# - Defense: the base damage resistance against normal attacks.
#
# - SP Atk: special attack, the base modifier for special attacks (e.g. fire blast, bubble beam).
#
# - SP Def: the base damage resistance against special attacks.
#
# - Speed: determines which pokemon attacks first each round.

# %% [markdown]
# ## Cleaning the DataFrame

# %% [markdown]
# Membuat seluruh nama kolom menjadi UPPERCASE

# %%
df.columns = df.columns.str.upper() # Changing all the column names to Upper case 
df.head()
# Out:
#    #                   NAME TYPE 1  TYPE 2  TOTAL  HP  ATTACK  DEFENSE  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    SP. ATK  SP. DEF  SPEED  GENERATION  LEGENDARY
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# Membuat kolom 'NAME' menjadi index dan menghapus kata sebelum kata 'Mega'

# %%
df.set_index('NAME',inplace=True)
df.index = df.index.str.replace(".*(?=Mega)", "")
df.head()
# Out:
# <ipython-input-14-5f7cc91ac961>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.index = df.index.str.replace(".*(?=Mega)", "")
#                # TYPE 1  TYPE 2  TOTAL  HP  ATTACK  DEFENSE  SP. ATK  SP. DEF  \
# NAME
# Bulbasaur      1  Grass  Poison    318  45      49       49       65       65
# Ivysaur        2  Grass  Poison    405  60      62       63       80       80
# Venusaur       3  Grass  Poison    525  80      82       83      100      100
# Mega Venusaur  3  Grass  Poison    625  80     100      123      122      120
# Charmander     4   Fire     NaN    309  39      52       43       60       50
#
#                SPEED  GENERATION  LEGENDARY
# NAME
# Bulbasaur         45           1      False
# Ivysaur           60           1      False
# Venusaur          80           1      False
# Mega Venusaur     80           1      False
# Charmander        65           1      False

# %% [markdown]
# Mengisi data yang kosong (NaN) di kolom Type 2 dengan Type 1. Disamakan saja dengan Type 1 karena faktanya tidak semua pokemon memiliki 2 tipe.

# %%
df['TYPE 2'] = df['TYPE 2'].fillna(value=df['TYPE 1'])

# %% [markdown]
# Hapus kolom '#'

# %%
df = df.drop(['#'],axis=1)

# %% [markdown]
# ## Data Exploration
#
# Ada berapa tipe Pokemon pada kolom TYPE 1?

# %%
def type_1():
    print('Tipe-tipe Pokemon di kolom TYPE 1 : \n\n',df['TYPE 1'].unique(),'\n')
    print('Total :',df['TYPE 1'].nunique(),'tipe pokemon\n\n')
    print('Jumlah pokemon dari setiap tipe pokemon pada TYPE 1\n\n',df['TYPE 1'].value_counts())

type_1()
# Out:
# Tipe-tipe Pokemon di kolom TYPE 1 :
#
#  ['Grass' 'Fire' 'Water' 'Bug' 'Normal' 'Poison' 'Electric' 'Ground'
#  'Fairy' 'Fighting' 'Psychic' 'Rock' 'Ghost' 'Ice' 'Dragon' 'Dark' 'Steel'
#  'Flying']
#
# Total : 18 tipe pokemon
#
#
# Jumlah pokemon dari setiap tipe pokemon pada TYPE 1
#
#  Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ghost        32
# Ground       32
# Dark         31
# Poison       28
# Fighting     27
# Steel        27
# Ice          24
# Fairy        17
# Flying        4
# Name: TYPE 1, dtype: int64

# %%
type_1_number = df['TYPE 1'].value_counts()
fig,ax = plt.subplots(figsize=(15,8))
ax.bar(type_1_number.index,type_1_number.values)

# This for loop is to place the value on top of the bar
for i in range(type_1_number.shape[0]):
    ax.text(i, type_1_number.values[i]+1, type_1_number.values[i], horizontalalignment='center')
ax.set_xlabel('Tipe Pokemon')
ax.set_ylabel('Jumlah')
ax.set_title('Count TYPE 1 of Pokemons')
plt.tight_layout()

# %% [markdown]
# *Dari sini kita dapat melihat bahwa pokemon tipe air adalah yang terbanyak di TYPE 1. Mari kita coba dengan TYPE 2*

# %%
def type_2():
    print('Tipe-tipe Pokemon di kolom TYPE 2 : \n\n',df['TYPE 2'].unique(),'\n')
    print('Total :',df['TYPE 2'].nunique(),'tipe pokemon\n\n')
    print('Jumlah pokemon dari setiap tipe pokemon pada TYPE 2\n\n',df['TYPE 2'].value_counts())

type_2()
# Out:
# Tipe-tipe Pokemon di kolom TYPE 2 :
#
#  ['Poison' 'Fire' 'Flying' 'Dragon' 'Water' 'Bug' 'Normal' 'Electric'
#  'Ground' 'Fairy' 'Grass' 'Fighting' 'Psychic' 'Steel' 'Ice' 'Rock' 'Dark'
#  'Ghost']
#
# Total : 18 tipe pokemon
#
#
# Jumlah pokemon dari setiap tipe pokemon pada TYPE 2
#
#  Flying      99
# Water       73
# Psychic     71
# Normal      65
# Grass       58
# Poison      49
# Ground      48
# Fighting    46
# Fire        40
# Fairy       38
# Electric    33
# Dark        30
# Dragon      29
# Ice         27
# Steel       27
# Ghost       24
# Rock        23
# Bug         20
# Name: TYPE 2, dtype: int64

# %%
type_2_number = df['TYPE 2'].value_counts()
fig,ax = plt.subplots(figsize=(15,8))
ax.bar(type_2_number.index,type_2_number.values)

# This for loop is to place the value on top of the bar
for i in range(type_2_number.shape[0]):
    ax.text(i, type_2_number.values[i]+1, type_2_number.values[i], horizontalalignment='center')
ax.set_xlabel('Tipe Pokemon')
ax.set_ylabel('Jumlah')
ax.set_title('Count TYPE 2 of Pokemons')
plt.tight_layout()

# %% [markdown]
# *Di sini kita dapat melihat bahwa pokemon tipe Flying adalah yang terbanyak di TYPE 2.*

# %% [markdown]
# #### *Siapakah pokemon dengan overall rating tertinggi?*

# %%
strong=df.sort_values(by='TOTAL', ascending=False)
strong
# Out:
#                         TYPE 1    TYPE 2  TOTAL   HP  ATTACK  DEFENSE  \
# NAME
# Mega Rayquaza           Dragon    Flying    780  105     180      100
# Mega Mewtwo Y          Psychic   Psychic    780  106     150       70
# Mega Mewtwo X          Psychic  Fighting    780  106     190      100
# KyogrePrimal Kyogre      Water     Water    770  100     150       90
# GroudonPrimal Groudon   Ground      Fire    770  100     180      160
# ...                        ...       ...    ...  ...     ...      ...
# Caterpie                   Bug       Bug    195   45      30       35
# Wurmple                    Bug       Bug    195   45      45       35
# Kricketot                  Bug       Bug    194   37      25       41
# Azurill                 Normal     Fairy    190   50      20       40
# Sunkern                  Grass     Grass    180   30      30       30
#
#                        SP. ATK  SP. DEF  SPEED  GENERATION  LEGENDARY
# NAME
# ...

# %% [markdown]
# *Mega Rayquaza, Mega Mewtwo Y dan Mega Mewtwo X adalah pokemon dengan overall tertinggi.*

# %%
def kombinasi_tipe ():
    df['TYPE 1-2'] = df['TYPE 1'] + " - " + df['TYPE 2']
    return df['TYPE 1-2'].value_counts()

def kombinasi_tipe_unik():
    df['TYPE 1-2'] = df['TYPE 1'] + "-" + df['TYPE 2']
    return df['TYPE 1-2'].nunique()

print("Jumlah kombinasi antara Tipe 1 dan 2: ",kombinasi_tipe_unik(),"Kombinasi")
print("\n\nJumlah pokemon dari setiap kombinasi tipe:\n\n",kombinasi_tipe())
# Out:
# Jumlah kombinasi antara Tipe 1 dan 2:  154 Kombinasi
#
#
# Jumlah pokemon dari setiap kombinasi tipe:
#
#  Normal - Normal      61
# Water - Water        59
# Psychic - Psychic    38
# Grass - Grass        33
# Fire - Fire          28
#                      ..
# Rock - Fighting       1
# Ice - Ghost           1
# Fire - Steel          1
# Dragon - Electric     1
# Electric - Water      1
# Name: TYPE 1-2, Length: 154, dtype: int64

# %% [markdown]
# *Mencari jumlah kombinasi tipe pokemon dan kombinasi tipe yang paling banyak.*
#
# - Terlihat bahwa kombinasi pokemon yang paling umum adalah Normal-Normal.
# - Total 154 kombinasi.

# %% [markdown]
# ## Kesimpulan

# %% [markdown]
# Dari hasil yang didapat di atas, kita dapat menarik beberapa kesimpulan:
#
# 1. Pokemon dataset ini awalnya terdiri dari 800 baris, 13 kolom dan berisi seluruh pokemon generasi 1-6 dari game pokemon berbagai macam konsol seperti Nintendo GBA, DS and Nintendo Switch.
#
# 2. Dari dataset diketahui ada 386 data yang kosong (Null values) pada kolom Type 2. Dikarenakan tidak semua pokemon memiliki dua type bersamaan. Namun agar mempermudah, data yang kosong tersebut diisikan nilainya sama dengan Type 1.
#
# 3. Pokemon terkuat adalah Mega Rayquaza dengan Total stat 780, diikuti oleh Mega Mewtwo Y dan Mega Mewtwo X dan termasuk dalam pokemon legenda.
#
# 4. Seperti namanya, pokemon legenda memiliki stat diatas rata-rata pokemon biasa. Terbukti dari Top 5 Pokemon Terkuat adalah pokemon legenda.
#
# 5. Pokemon generasi terbaru tidak menjamin akan lebih kuat dari pokemon generasi sebelumnya. Terbukti dari Top 5 Pokemon Terkuat adalah pokemon dari generasi lawas.
#
# 6. Terdapat 18 tipe pokemon dan 136 kombinasi dari Tipe 1 dan Tipe 2. Dan kombinasi tipe pokemon 'Normal-Flying' adalah kombinasi yang paling banyak (umum).
